# %% [markdown]
# # A task has been created in Asana tool and the same is emailed to the user

# %%
import requests
from datetime import datetime

def create_task(api_token, workspace_id, project_id, task_name, assignee_id, due_date):
    headers = {
        'Authorization': f'Bearer {api_token}',
        'Content-Type': 'application/json'
    }

    data = {
        'data': {
            'workspace': workspace_id,
            'projects': [project_id],
            'name': task_name,
            'assignee': assignee_id,
            'due_on': due_date.strftime('%Y-%m-%d')
        }
    }

    response = requests.post('https://app.asana.com/api/1.0/tasks', headers=headers, json=data)

    if response.status_code == 201:
        return response.json()['data']
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None


# Example usage
api_token = '1/1204695278604361:eab381334a69c228578926646fb70ab1'
workspace_id = '76786340109967'
project_id = '1204695278739271'
task_name = 'Meeting Scheduler'
assignee_id = '1204695278604376'
due_date = datetime(2023,5,30)  # Format: YYYY-MM-DD

task_id = create_task(api_token, workspace_id, project_id, task_name, assignee_id, due_date)
if task_id:
    print(f"Task created with ID: {task_id}")
# Out:
# Task created with ID: {'gid': '1204700224420518', 'projects': [{'gid': '1204695278739271', 'resource_type': 'project', 'name': 'Our first project'}], 'resource_type': 'task', 'created_at': '2023-05-30T06:26:42.211Z', 'modified_at': '2023-05-30T06:26:42.612Z', 'name': 'Meeting Scheduler', 'notes': '', 'parent': None, 'actual_time_minutes': 0, 'completed': False, 'completed_at': None, 'due_on': '2023-05-30', 'due_at': None, 'resource_subtype': 'default_task', 'start_on': None, 'start_at': None, 'tags': [], 'workspace': {'gid': '76786340109967', 'resource_type': 'workspace', 'name': 'fissionlabs.com'}, 'num_hearts': 0, 'num_likes': 0, 'memberships': [{'project': {'gid': '1204695278739271', 'resource_type': 'project', 'name': 'Our first project'}, 'section': {'gid': '1204695278739272', 'resource_type': 'section', 'name': 'To do'}}], 'assignee': {'gid': '1204695278604361', 'resource_type': 'user', 'name': 'laalini.b'}, 'hearts': [], 'likes': [], 'permalink_url': 'https://app.asana.com/0/1
# ...

# %%
//send emails to panel

import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

def send_emails(emails, subject, message):
    # Email configuration
    smtp_host = 'YOUR_SMTP_HOST'
    smtp_port = 587
    smtp_username = 'YOUR_SMTP_USERNAME'
    smtp_password = 'YOUR_SMTP_PASSWORD'
    sender_email = 'SENDER_EMAIL_ADDRESS'
    
    for recipient_email in emails:
        # Create a multipart message
        msg = MIMEMultipart()
        msg['From'] = sender_email
        msg['To'] = recipient_email
        msg['Subject'] = subject

        # Add the message content
        body = message  # Replace with your template or custom message
        msg.attach(MIMEText(body, 'plain'))

        # Create an SMTP session and send the email
        with smtplib.SMTP(smtp_host, smtp_port) as server:
            server.starttls()
            server.login(smtp_username, smtp_password)
            server.send_message(msg)

        print(f"Email sent to: {recipient_email}")

# Example usage
email_list = ['recipient1@example.com', 'recipient2@example.com', 'recipient3@example.com']
email_subject = 'Meeting Invitation'
email_message = '''
Dear Participant,

You are invited to a meeting on Tuesday at 2:00 PM.

Please confirm your availability.

Best regards,
Your Name
'''

send_emails(email_list, email_subject, email_message)

# %%
# Import the following module
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.application import MIMEApplication
from email.mime.multipart import MIMEMultipart
import smtplib
import os

# initialize connection to our
# email server, we will use gmail here
smtp = smtplib.SMTP('smtp.gmail.com', 587)
smtp.ehlo()
smtp.starttls()

# Login with your email and password
smtp.login('sendersemailid', 'senderspassword')


# send our email message 'msg' to our boss
def message(subject="We are impressed with your experience and background in "+ skill + "Please can you let us know if you are interested in "+ Job title +"position at Fissionlabs."+Joblink,
			text="", img=None,
			attachment=None):
	
	# build message contents
	msg = MIMEMultipart()
	
	# Add Subject
	msg['Subject'] = 'Test email'
	
	# Add text contents
	msg.attach(MIMEText(text))

	

# Call the message function
msg = message("Good!", "Hi there!",
		)

# Make a list of emails, where you wanna send mail
to = ["receiversemailid"]

# Provide some data to the sendmail function!
smtp.sendmail(from_addr="sendersemailid",to_addrs=to,msg= "Hi There")

# Finally, don't forget to close the connection
smtp.quit()
